# %% [markdown]
# # ダッシュボード起動
#
# 東京エリアのv5スコア（ML Gap のみ）でダッシュボードを起動する。http://127.0.0.1:8050 でアクセス可能。

# %%
import sys
sys.path.insert(0, "..")

from src.visualize.dashboard import run_dashboard

run_dashboard(tag="tokyo")
